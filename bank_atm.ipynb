# %%
class Bank:
    acbal = 10000
    count = 0
    def withdraw(self):
        if Bank.count == 3:
            print("Daily transaction limit reached")
            return
        amt = int(input("Enter your withdraw amount :"))
        five = 0
        two = 0
        if amt % 100 == 0:
            if amt <= 20000:
                if amt <= Bank.acbal:
                    Bank.acbal = Bank.acbal - amt
                    Bank.count += 1
                    print("Available bal :", Bank.acbal)
                    if amt >= 500:
                        five = amt // 500
                        amt = amt - (five * 500)
                        print("500 ------:", five)
                    if amt >= 200:
                        two = amt // 200
                        amt = amt - (two * 200)
                        print("200 ------:", two)
                    if amt == 100:
                        print("100 ------:", amt // 100)
                else:
                    print("Insufficient fund")
            else:
                print("Withdraw limit is 20k only")
        else:
            print("Please enter multiples of 100 only")

    def deposite(self):
        if Bank.count == 3:
            print("Daily transaction limit reached")
            return
        amt = int(input("Enter your deposite amount: "))
        five = 0
        two = 0
        if amt % 100 == 0:
            Bank.acbal = Bank.acbal + amt
            Bank.count += 1
            print("Available bal :", Bank.acbal)
            if amt >= 500:
                five = amt // 500
                amt = amt - (five * 500)
                print("500 ------:", five)
            if amt >= 200:
                two = amt // 200
                amt = amt - (two * 200)
                print("200 ------:", two)
            if amt == 100:
                print("100 ------:", amt // 100)
        else:
            print("Please enter multiples of 100 only")

    def viewOptions(self):
        while True:
            print("\n1. deposite")
            print("2. withdraw")
            print("3. bal Enquiry")
            print("0. EXIT")

            option = int(input("Choose your option: "))

            if option == 1:
                obj.deposite()
            elif option == 2:
                obj.withdraw()
            elif option == 3:
                print("Available bal :", Bank.acbal)
            elif option == 0:
                print("Thank you, visit again")
                break
            else:
                print("Invalid option")

            ch = input("Press C to continue or any key to exit: ").lower()
            if ch != 'c':
                print("Thank you, visit again")
                break


obj = Bank()
obj.viewOptions()
# Out:
# 1. deposite
# 2. withdraw
# 3. bal Enquiry
# 0. EXIT
# Choose your option:  1
# Enter your deposite amount:  2300
# Available bal : 12300
# 500 ------: 4
# 200 ------: 1
# 100 ------: 1
# Press C to continue or any key to exit:  c
# 1. deposite
# 2. withdraw
# 3. bal Enquiry
# 0. EXIT
# Choose your option:  2
# Enter your withdraw amount : 3400
# Available bal : 8900
# 500 ------: 6
# 200 ------: 2
# Press C to continue or any key to exit:  e
# Thank you, visit again
